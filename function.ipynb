# %% [markdown]
# # What is a Function?

# %% [markdown]
# A function is a group of statements or a block of code to perform a certain task.
#
# The advantages of using functions are:
#  -   Maintaining the code is an easy way.
#  -   Organize and manage our code
#  -   Code re-usability.

# %% [markdown]
#     Types of functions
#
# There are many categories based on which we can categorize the functions.
#
# - 1. Pre-defined or built-in functions
# - 2. User-defined functions

# %% [markdown]
#     Predefined or built-in functions
#
# The functions which come installed along with python software are called predefined or built-in functions. We have covered some inbuilt functions in examples of earlier chapters. Some of them are id(), type(),input(), print() etc.

# %% [markdown]
#     User-defined functions
# The functions which are defined by the developer as per the requirement are called as user defined functions.
# In this chapter we shall concentrate on these kind of functions which are used defined.

# %% [markdown]
#     How to Create and call a Function?
#
# From creating a function to using it, these are the two things that are done.
#
# Defining function
#
# Calling function
#
#     1. Defining a function
# **Syntax to define function**
#
# def function_name(parameters):
#
# // body of function
#
# return value
#
# **def keyword** – Every function in python should start with the keyword ‘def’. In other words, python
# can understand the code as part of a function if it contains the ‘def’ keyword only.
#
# PS. ‘def’ means define a function.
#
# **Name of the function** – Every function should be given a name, which can later be used to call it.
#
# **Parenthesis** – After the name ‘()’ parentheses are required
#
# **Parameters** – The parameters, if any, should be included within the parenthesis.
#
# **Colon symbol** ‘:’ should be mandatorilyplaced immediately after closing the parentheses.
#
# **Body of function** – All the code that does some operation should go in the body of the function. The body of the function should have indentation of one level with respect to the line containing the ‘def’ keyword.
#
# **Return value /statement/**– Return statement should be in the body of the function. It’s not mandatory to have a return statement.

# %%
# define a function

def add():
    a,b=1,2
    c=a+b
    return c

# %% [markdown]
#     2. Calling a function
#
# In the above example we defined a function with the name ‘add’ to add two nos. But when we execute the above code, it will not display any output, because the function is not called. Hence, function calling is also important along with function definition.
#
# **Note: When a function is called once then it will execute once, if called twice then it will be executed twice and so on.**
#
# Syntax to call a function:
#
# function_name(parameters)

# %%
# calling function

add()
# Out:
# 3

# %% [markdown]
# While calling the function, we have to call with the same name of the function which we used while defining it, otherwise we will get an error.

# %%
# define a function ( Define a function & call it with different name )

def add():
    a,b=2,3
    c=a+b
    return c

two()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5     c=a+b
#       6     return c
# ----> 8 two()
#
# NameError: name 'two' is not defined

# %%
def  avg():
    a,b=1,2
    c=(a+b)/2
    return c

avg()
# Out:
# 1.5

# %% [markdown]
#     Based on the parameters, functions can be categorized into two types.
#
# They are:
#
# - Function without parameters (Non-parametric Function)
# - Function with parameters (Parametric Function)

# %% [markdown]
# **What is Non-parametric function?**
#
# A function which has no parameters in the function definition is called as Non-parametric function or function without parameters.
#
# Syntax of non-parametric function:
#
# def function_name():
#
# // body of function
#
# return value

# %%
#defining a function 
def display():
    print('Wellcome to the faceboook')
    
# calling function 
display()
# Out:
# Wellcome to the faceboook

# %% [markdown]
#     What is Parametric function?
#
# A function which has parameter(s) in the function definition as an input is called as parametric function or
# function with argument.
#
#     What is Argument?
# An argument is a variable (which contains data) or a parameter which is sent to the function as input.

# %% [markdown]
#     1. Formal arguments
#
# When a function is defined it (may) has (have) some parameters within the parentheses. These parameters, which receive the values sent from the function call, are called formal arguments.
#
#     2. Actual arguments
#
# The parameters which we use in the function call or the parameters which we use to send the values/data during the function calling are called actual arguments.
#
# In the example down below:
#
# a and b are formal arguments.
#
# 7 and 3 are actual arguments.

# %%
def add(a,b):
    c=a+b
    return c

add(7,3)
# Out:
# 10

# %%
#Create a parametric function to check a number is even or odd?

def even(n):
    return n%2==0


def odd(n):
    return n%2==1

# %% [markdown]
#     Types of Arguments
#
# - 1. Positional arguments
# - 2. Keyword arguments
# - 3. Default arguments
# - 4. Variable length arguments
# - 5. keyword variable length argument

# %% [markdown]
#     1. Positional Arguments
#
# If there are three arguments (formal arguments) in the function definition, then you need to send three
# arguments(actual arguments) while calling the function. The actual arguments will be received by the formal
# arguments in the same order as in the function calling.

# %%
#defining the function

def sub(a,b):
    c=a-b
    return c

sub(10,22)
# Out:
# -12

# %%
def sub(a,b):
    a-=b
    return a

sub(100,22)
# Out:
# 78

# %%
def sub(a,b):
    c=a-b
    return c

sub(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2     c=a-b
#       3     return c
# ----> 5 sub(1,2,3)
#
# TypeError: sub() takes 2 positional arguments but 3 were given

# %% [markdown]
#     2. Keyword Arguments
#
# In the function call, if we send the values using keys then they are called keyword arguments. Here, keys are
# nothing but the names of the variables. In a way, we can say that keyword arguments are arguments that
# recognize the parameters by the name of the parameters.

# %%
def sub(a,b):
    c=a-b
    return c

sub(b=2,a=11)
# Out:
# 9

# %% [markdown]
#     3. Positional and keyword arguments
#
# We can use both positional and keyword arguments simultaneously. But first we must take positional
# arguments and then keyword arguments, otherwise we will get syntax error.

# %%
def sub(a,b):
    c=a-b
    return c

sub(1,b=22)
# Out:
# -21

# %%
sub(b=22,1)
# Out:
#   Cell In[10], line 1
#     sub(b=22,1)
#               ^
# SyntaxError: positional argument follows keyword argument

# %%
def brand(a,b):
    return a,b

brand('Realme',12000)
# Out:
# ('Realme', 12000)

# %%
# defining a function

def sub(a, b):
    c = a - b
    print(c)
    
# calling function
sub(a=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       5     print(c)
#       7 # calling function
# ----> 8 sub(a=5)
#
# TypeError: sub() missing 1 required positional argument: 'b'

# %% [markdown]
#     4. Default Arguments
# In the function definition, while declaring parameters, we can assign some value to the parameters, which are
# called default values. Such default values will be considered when the function call does not send any data to
# the parameter.
#
# Let’s take earlier function as an example. There, the function sub() has parameters as a and b. To resolve
# TypeError, we can set the default value of b as 0, then default values will be overridden with passed value.

# %%
# defining a function
def sub(a, b=0):
    c = a - b
    print(c)
    
# calling a function
sub(a=5, b=2)

# calling a function
sub(a=5)
# Out:
# 3
# 5

# %%
# Default arguments Error 
# defining a function
def add(a=3, b):
    print(a + b)
    
# calling a function
add(a=5, b=2)

# calling a function
add(a=9,b)
# Out:
#   Cell In[23], line 3
#     def add(a=3, b):
#                  ^
# SyntaxError: non-default argument follows default argument

# %% [markdown]
#     Note: If we are not passing any value, then only default value will be considered. While defining a function,after default arguments we should not take non-default arguments.

# %% [markdown]
#     5. Variable Length Arguments
#
# Sometimes, the programmer (you) does not know how many values need to pass to function. In that case, the
# programmer cannot decide how many arguments to be given in the function definition. Therefore, we use
# variable length arguments to accept n number of arguments.
#
# The variable length argument is an argument that can accept any number of values.
#
# The variable length argument is written with a ‘*’ (one star) before variable in function definition.
#
# Syntax for Variable length Arguments:
#
# def function_name(x, *y):
#
# //body of function
#
# return value
#
# x is formal argument, *y is variable length argument. Now we can pass any number of values to this *y.

# %%
#variable lenth function  defining a function

def detail(name, *others):
    print(name, others)
    
    
# calling a function
detail("John")

# calling a function
detail("John", 20)

# calling a function
detail("John", 20, 3.7)
# Out:
# John ()
# John (20,)
# John (20, 3.7)

# %%
#variable lenth function  defining a function using return function

def detail(name, *others):
    return(name, others)
    
    
# calling a function
detail("John")

# calling a function
detail("John", 20)

# calling a function
detail("John", 20, 3.7)
# Out:
# ('John', (20, 3.7))

# %%
def players(name,*others):
    print(name,others)
    
#calling function
players('giri',2002,19,2)
# Out:
# giri (2002, 19, 2)

# %%
#defining a function

def detail(**others):
    print(others)
    
# calling a function
detail(name='John', age=20, gpa=3.7)
# Out:
# {'name': 'John', 'age': 20, 'gpa': 3.7}

# %% [markdown]
#    ![image.png](attachment:image.png)

# %%
#defining function calling function

# defining a function

def add(a,b):
    return(a+b)

# defining a function

def average(a,b):
    sum = add(a,b)
    avg = sum / 2
    print("Average =",avg)
    
# calling a function
average(7,3)
# Out:
# Average = 5.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#defining function

def average(a, b):
    
    #Defining second function
    
    def add():
        return a+b
    
    #calling a fun 1
    sum = add()
    
    avg = sum//2
    print('average: ',avg)

#calling function 2
average(10,22)
# Out:
# average:  16

# %% [markdown]
#     keyword variable length argument (**variable)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#defining the function

def details(**others):
    return(others)

#calling function
details(name='giri',age='22',gpa='6.31')
# Out:
# {'name': 'giri', 'age': '22', 'gpa': '6.31'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Function returning the value as variable

def add(a,b):
    return a+b

#calling Function
x = add(1,2)

print('Function as avariable:', x)
# Out:
# Function as avariable: 3

# %% [markdown]
# **What is Recursive Function?**
#
# A function is called recursive when it is called by itself. Let’s understand this with an example.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Factorial using recursive function

#defining the function

def factorial(n):
    if n == 0:
        result = 1
    else:
        result = n * factorial(n-1)
    
    
    return result

factorial(7)
# Out:
# 5040

# %% [markdown]
# **Advantages of using recursive functions:**
#
# - We can reduce length of the code and improves readability.
# - We can solve complex problems in a very easy way.

# %% [markdown]
# **Types of Variables**
#
# They are classified into two types based on their properities.
#
# - 1. Local Variable
# - 2. Global Variable

# %% [markdown]
# **1. Local Variables**
#
# The variables which are declared inside of the function are called as local variables. Their scope is limited to the function
#
# i.e. we can access local variables within the function only.

# %%
# Local Variables 

#defining the function
def add():
    a,b = 5,2
    print(a+b)

#calling Function
add()
# Out:
# 7

# %% [markdown]
#     If we are trying to access local variables outside of the function, then we will get an error.

# %%
#DEFINING THE FUNCTION 

def add():
    a,b=1,2
    print(a+b)

#calling Function
add()

def Sub():
    print(a-b)

#calling Function
sub()
# Out:
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11     print(a-b)
#      13 #calling Function
# ---> 14 sub()
#
# NameError: name 'sub' is not defined

# %% [markdown]
# **2. Global Variables**
#
# The variables which are declared outside of the function are called global variables. Global variables can be accessed in all functions.

# %%
#Global variable 

a, b =10, 22

#defining the fun
def add():
    print(a+b)

#calling function
add()

def sub():
    print(a-b)

sub()
# Out:
# 32
# -12

# %% [markdown]
# **When can we choose a global keyword?**
#
# There might be some scenarios, where the global variable names and local variable names are the same. In such cases, within the function, by default, the local variables are only referred and the global variables are ignored.

# %%
def add():
    a=20
    print(a+b)

add()

def sub():
    b=10
    print(a-b)

sub()
# Out:
# 42
# 0

# %% [markdown]
# ***If we want our function to refer to global variable rather than the local variable, we can use global keyword before the variable in the function as shown in the example below.***

# %%
def add():
    global a
    a = 20
    print(a+b)

def sub():
    b=20
    print(a-b)
    
add()
sub()
# Out:
# 42
# 0

# %% [markdown]
# 1. To declare global variable inside function.
#
# 2. To make global variables available to the function.

# %% [markdown]
# **PROBLEM: This would make the local variable no more available.**
#
# How to solve this problem?
#
# globals() built-in function
#
# The problem of local variables not available, due to use of global keyword can be overcome by using Python built-in function called globals() .
#
# globals() is a built in function which returns a table of current global variables in the form of a dictionary.
#
# Using this function, we can refer to the global variable as:

# %%
a, b = 5, 2

# defining a function
def add():
    a = 9
    print(a + b)
    print(globals()['a'] + b)

# calling a function
add()
# Out:
# 11
# 7
